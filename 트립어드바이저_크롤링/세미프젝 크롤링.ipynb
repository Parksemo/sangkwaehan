# %%
import numpy as np
import pandas as pd
import csv

from selenium import webdriver
import chromedriver_autoinstaller

from tqdm import tqdm, tqdm_notebook
from tqdm.notebook import tqdm
import re
from time import sleep
import time
import warnings
warnings.filterwarnings('ignore')
import random
t=random.choice([3,4,5])

# %%
def 리뷰크롤링(key):
    chrome_path=chromedriver_autoinstaller.install()
    driver = webdriver.Chrome(chrome_path)
    time.sleep(3)
    try:
        driver.get("https://www.tripadvisor.co.kr/")
        time.sleep(5)
        find=driver.find_element_by_xpath('//*[@id="lithium-root"]/main/div[3]/div/div/div/form/input[1]')
        driver.implicitly_wait(10)
        find.send_keys(key)
        time.sleep(7)
        find.submit()#엔터
        driver.implicitly_wait(10)
        driver.find_element_by_xpath('//*[@id="BODY_BLOCK_JQUERY_REFLOW"]/div[2]/div/div[2]/div/div/div/div/div[1]/div/div[1]/div/div[3]/div/div[1]/div/div[2]/div/div/div[1]/div/div/div/div[2]/div/div[1]').click()
        driver.implicitly_wait(10)
        driver.switch_to.window(driver.window_handles[-1])
        time.sleep(5)
    except:
        driver.get("https://www.tripadvisor.co.kr/")
        time.sleep(5)
        find=driver.find_element_by_xpath('//*[@id="lithium-root"]/main/div[3]/div/div/div/form/input[1]')
        driver.implicitly_wait(10)
        find.send_keys(key)
        time.sleep(7)
        find.submit()#엔터
        driver.implicitly_wait(10)
        driver.find_element_by_xpath('//*[@id="BODY_BLOCK_JQUERY_REFLOW"]/div[2]/div/div[2]/div/div/div/div/div[1]/div/div[1]/div/div[3]/div/div[1]/div/div[2]/div/div/div[1]/div/div/div/div[2]/div/div[1]').click()
        driver.implicitly_wait(10)
        driver.switch_to.window(driver.window_handles[-1])
        time.sleep(5)
    file_name = driver.find_element_by_xpath('//*[@id="lithium-root"]/main/div[1]/div[2]/div[1]/header/div[3]/div[1]/div/h1').text
    out_re=[]
    c = True
    while c:   
        try:
            driver.execute_script("window.scrollTo(0, 5500)")
            driver.implicitly_wait(t)
            for j in tqdm(range(1,11)):
                #time.sleep(2)
                try:
                    review=[driver.find_element_by_xpath(f'//*[@id="tab-data-qa-reviews-0"]/div/div[5]/div[{j}]/span/div/div[5]/div[1]/div/span').text
                           ,driver.find_element_by_xpath(f'//*[@id="tab-data-qa-reviews-0"]/div/div[5]/div[{j}]/span/div/div[2]/*[name()="svg"]').get_attribute('aria-label')
                           ,driver.find_element_by_xpath('//*[@id="tab-data-qa-reviews-0"]/div/div[3]/span/div/div[1]/div[2]/span').text
                           ]
                    review[1] = review[1].replace('풍선 5개 중 ','')
                    review[2]=review[2].replace("리뷰 ","").replace("건","")
                    #time.sleep(t)
                    out_re.append(review)
                except:
                    break
            driver.implicitly_wait(t)
    #         print(out_re)
            element = driver.find_element_by_xpath('//*[@id="tab-data-qa-reviews-0"]/div/div[5]/div[10]/span/div')
            driver.execute_script('arguments[0].scrollIntoView(true);', element)
            driver.find_element_by_xpath('//*[@id="tab-data-qa-reviews-0"]/div/div[5]/div[11]/div[1]/div/div[1]/div[2]/div/a/*[name()="svg"]').click()
            driver.implicitly_wait(t)
        except:
            c=False
    title="리뷰","평점","리뷰수"
    f=open(f"{file_name}.csv","w",encoding='utf-8-sig',newline="")
    writer=csv.writer(f)
    writer.writerow(title)
    writer.writerows(out_re)
    f.close()   
    df=pd.read_csv(f'{file_name}.csv')
    return df

# %%
리뷰크롤링("수변공원")
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#                                                    리뷰   평점  리뷰수
# 0   수변공원에서 돗자리깔고 회먹으니까 분위기 좋았어요! 사람이 많아수 조금 힘들었지만 ...  4.0   55
# 1   겨울에도 일단 사람이 적진 않고\n그 유명한 민락횟집 뷰를 볼 수 있음\n겨울에는 ...  4.0   55
# 2   광안리해수욕장의 모래해변 끝까지 간 다음에 민락수변도로를 따라서 걷다보면 바닷가에 ...  4.0   55
# 3   바다보면서 회랑 술한잔 하는 분위기는 좋았으나 다들 지적하듯 쓰레기 처리를 제대로 ...  4.0   55
# 4   겨울에 가도 참 좋은 곳입니다.\n여름에 가끔씩 친구들이랑 들르는데\n회를 떠서 맛...  5.0   55
# 5   낮이나 밤에 다 가기 좋지만 저녁에 가는게 시원하고 좋아요. 돗자리 가져가서 회떠서...  3.0   55
# 6   주변 회센터에서 회를 포장해온 사람들이 몰려 술 한 잔 하는 곳입니다. 사람이 많아...  3.0   55
# 7   근처에 살아서 산책하러 자주 가는데 광안대교도 잘 보이고 뷰는 좋긴한데 야외에서 술...  1.0   55
# 8   광안대교 보면서 술마시기에 좋습니다. 하지만 사람 많을때는 쓰래기 냄새가 심해요 깨...  3.0   55
# 9   여름에 회를 사서 먹기 좋아요. 민락수변공원 근처에서 판매하는 돗자리에 앉아서 보내...  5.0   55
# 10  민락회센터가서 회를 사오세여.. 밀치회 존맛이랍니다..\n밀치회 2.5KG?에 2만...  5.0   55
# 11  광안리 해수욕장보다 이곳에서 바라보는 광안대교가 좀 더 압도적이고 좋습니다. 여름에...  4.0   55
# 12  회센터에서 회떠다가 수변공원에서 먹기 딱 좋아요. 대신 지금은 너무 춥고 따뜻해질때...  4.0   55
# 13  바다 바로 옆에서 회 마시며 술 한잔 할 수 있는 곳이에요. 우리가 흔히 아는 공원...  4.0   55
# 14  민락수변공원 옆의 밀레니엄횟집은 회도 맛있고 방에서 보이는 고안대교의 전경이 멋진 ...  3.0   55
# 15  날씨가 좋을때- 춥지도 덥지도 않을때\n치킨이나 회 사들고 와서 먹기 좋은것 같아요...  4.0   55
# 16  일출을 보러 갔는데 굳이 멀리가지 않아도 잘 보이더라구요. 커피피를 파는곳도 여러곳...  5.0   55
# 17  광안대교를 보며 바닷길을 따라 걷기 좋습니다. 광고사진처럼 예쁜 사진을 남길 수 있...  4.0   55
# 18  자전거 도로가 있지만 깨끗하다기 보다 무너가 좀 지전분합니다. 다만, 2번 와봤지만...  3.0   55
# 19  민락수변공원은 시민들에게 개방된 피크닉 장소라고 할 수 있다. 시원한 바닷바람을 벗...  4.0   55
# 20  여름에 한번씩 돗자리 들고 꼭 찾아가는 곳 중 하나입니다.\n이제는 하나의 관광명소...  4.0   55
# 21  광안대교 야경과 회를 즐기기에 좋은 곳.\n가능하면 낮이 아닌 저녁에 가서 야경을 ...  3.0   55
# 22  햇살이 뜨거워 앉을수가 없었지만 부산을 왓다는 신념하나로 광안리근처를 접수 주말이라...  5.0   55
# 23  근처에 민락활어직판장에서 회 한 접시 포장해서 광안대교가 잘 보이는 곳에 자리를 잡...  4.0   55
# 24  부산 가볼만한 곳으로 추천받아서 광안리 해수욕장 가는김에 들러봤어요~~\n민락동은 ...  4.0   55
# 25  광안대교가 가까이서 보여요. 회센터가 많아서 회도 즐기고 잠시 교외에 나온듯한 나들...  3.0   55
# 26  민락동 회센터에서 회 한접시 먹고 나서 민락수변공원 산책은 매우 산뜻합니다.\n저녁...  5.0   55
# 27  광안리해수욕장에서 걸어서 25분 정도면 민락수변공원을 만날 수 있습니다. 대중교통을...  4.0   55
# 28  여름날 민락수변공원에 돗자리나 신문지를 펴고 노상으로 회 한접시 먹는 것이 참 맛있...  5.0   55
# 29  바로 앞에 회센터가 있으며 광안대교 바로 앞입니다.\n시원하게 한잔하기도 좋은 곳이...  5.0   55
# 30  여름철 회타운에서 회 떠서 맥주사서 수변공원에 신문지 깔고 앉아먹으면 캬 맛좋고 분...  5.0   55
# 31  가족, 친구들끼리 부담없이 나들이 갈 수 있는 최적의 장소입니다.\n근처에서 회를 ...  4.0   55
# 32  저녁노을이 질때 즈음 돗자리를 깔고 지는 해를 바라보며 먹는 야식의 즐거움은 해보지...  4.0   55
# 33  외지인들이 모를 때에는 조용하게 광안대교 야경을 바라볼 수 있어서 정말 좋았는데, ...  4.0   55
# 34  저렴한 회를 먹으며 바다를 바라보는 재미...\n접근 또한 용이해 좋은 곳이다.\n...  5.0   55
# 35  위치도 좋고, 탁 트여진 바닷가를 감상하면서 회와 술 한잔 곁들일 수 있는 곳입니다...  4.0   55
# 36  더운 여름날 부산사람들이 가는 곳 중 하나가 수변공원이다. 데이트 하는 남녀, 가족...  3.0   55
# 37  낮에는 바다의 낭만이, 밤에는 멋진 광안대교가 야경을 빛내며 바로 앞에 자리하고 있...  5.0   55
# 38  여름에 사람들이 너무 많습니다. 먹고간 음식들은 제발 치우고 가는 시민의식이 필요해...  3.0   55
# 39  여름에 수변공원에서 회 포장해와서 먹는 맛은 안 먹어본 사람은 모르죠. 가격도 저렴...  5.0   55
# 40  민락 수변공원은 야간에 가면 광안대교 야경이 멋지고 근처 횟집에서 회를 사서 방파제...  4.0   55
# 41  성수기를 피해서 가본 민락수변공원은 조용하고 좋았어요. 도보로 5분거리에 있는 회센...  4.0   55
# 42  완전 좋아요... 여름에 수변공원에 돗자리 펴놓고 회센타에서 회 떠다가 소주한잔 하...  5.0   55
# 43  부산을 느낄수있는곳!!\n부산에 계속 살고 있는 친구는 이곳이 너무 관광객이 많다고...  5.0   55
# 44  이 근처에 회 정말 저렴하게 팔아요!!! 그래서 저녁에 친구들이랑 회 한접시 사서 ...  5.0   55
# 45  부산에서 회를 싸게 먹을 수 있는 곳이 수변공원의 회센터이다. 여기서 판매하는 분들...  5.0   55
# 46  수변공원에 돗자리를 깔고 바로 앞에 회센터에서 회를 사다가 먹으면 된다.\n어두워지...  5.0   55
# 47  멋진 장소 멋진 다리 같은 경치를 즐길 수 있... 아름답지만 매우 더운 날 밤에....  4.0   55

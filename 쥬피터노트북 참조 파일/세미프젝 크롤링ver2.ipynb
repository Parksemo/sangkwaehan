# %%
import numpy as np
import pandas as pd
import csv

from selenium import webdriver
import chromedriver_autoinstaller

from tqdm import tqdm, tqdm_notebook
from tqdm.notebook import tqdm
import re
from time import sleep
import time
import warnings
warnings.filterwarnings('ignore')
import random
import pickle
t=random.choice([3,4,5])

# %%
def 리뷰크롤링(key):
    chrome_path=chromedriver_autoinstaller.install()
    driver = webdriver.Chrome(chrome_path)
    time.sleep(3)
    try:
        driver.get("https://www.tripadvisor.co.kr/")
        time.sleep(5)
        find=driver.find_element_by_xpath('//*[@id="lithium-root"]/main/div[3]/div/div/div/form/input[1]')
        driver.implicitly_wait(10)
        find.send_keys(key)
        time.sleep(7)
        find.submit()#엔터
        driver.implicitly_wait(10)
        driver.find_element_by_xpath('//*[@id="BODY_BLOCK_JQUERY_REFLOW"]/div[2]/div/div[2]/div/div/div/div/div[1]/div/div[1]/div/div[3]/div/div[1]/div/div[2]/div/div/div[1]/div/div/div/div[2]/div/div[1]').click()
        driver.implicitly_wait(10)
        driver.switch_to.window(driver.window_handles[-1])
        time.sleep(5)
    except:
        driver.get("https://www.tripadvisor.co.kr/")
        time.sleep(5)
        find=driver.find_element_by_xpath('//*[@id="lithium-root"]/main/div[3]/div/div/div/form/input[1]')
        driver.implicitly_wait(10)
        find.send_keys(key)
        time.sleep(7)
        find.submit()#엔터
        driver.implicitly_wait(10)
        driver.find_element_by_xpath('//*[@id="BODY_BLOCK_JQUERY_REFLOW"]/div[2]/div/div[2]/div/div/div/div/div[1]/div/div[1]/div/div[3]/div/div[1]/div/div[2]/div/div/div[1]/div/div/div/div[2]/div/div[1]').click()
        driver.implicitly_wait(10)
        driver.switch_to.window(driver.window_handles[-1])
        time.sleep(5)
    file_name = driver.find_element_by_xpath('//*[@id="lithium-root"]/main/div[1]/div[2]/div[1]/header/div[3]/div[1]/div/h1').text
    out_re=[]
    c = True
    while c:   
        try:
            driver.execute_script("window.scrollTo(0, 5500)")
            driver.implicitly_wait(t)
            for j in tqdm(range(1,11)):
                #time.sleep(2)
                try:
                    review=[driver.find_element_by_xpath(f'//*[@id="tab-data-qa-reviews-0"]/div/div[5]/div[{j}]/span/div/div[5]/div[1]/div/span').text
                           ,driver.find_element_by_xpath(f'//*[@id="tab-data-qa-reviews-0"]/div/div[5]/div[{j}]/span/div/div[2]/*[name()="svg"]').get_attribute('aria-label')
                           ]
                    review[1] = review[1].replace('풍선 5개 중 ','')
                    reviews=driver.find_element_by_xpath('//*[@id="tab-data-qa-reviews-0"]/div/div[3]/span/div/div[1]/div[2]/span').text
                    reviews=reviews.replace("리뷰 ","").replace("건","")
                    #time.sleep(t)
                    out_re.append(review)                    
                except:
                    break
            driver.implicitly_wait(t)
    #         print(out_re)
            element = driver.find_element_by_xpath('//*[@id="tab-data-qa-reviews-0"]/div/div[5]/div[10]/span/div')
            driver.execute_script('arguments[0].scrollIntoView(true);', element)
            driver.find_element_by_xpath('//*[@id="tab-data-qa-reviews-0"]/div/div[5]/div[11]/div[1]/div/div[1]/div[2]/div/a/*[name()="svg"]').click()
            driver.implicitly_wait(t)
        except:
            c=False
    리뷰크롤링_리뷰수={}
    리뷰크롤링_리뷰수['리뷰'] = out_re
    리뷰크롤링_리뷰수['리뷰수']  = reviews
    with open(f"{file_name}_.pickle","wb") as fw:
        pickle.dump(리뷰크롤링_리뷰수, fw)    
#     title="리뷰","평점"  
#     f=open(f"{file_name}.csv","w",encoding='utf-8-sig',newline="")
#     writer=csv.writer(f)
#     writer.writerow(title)
#     writer.writerows(out_re)
#     f.close()   
#     df=pd.read_csv(f'{file_name}.csv')
#     df_ver=pd.DataFrame(크롤링_리뷰수['리뷰']).insert(column=["리뷰","평점"])

# %%
리뷰크롤링("용지문화공원")
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
reviews
# Out:
# '40'

# %%
with open("용지문화공원_.pickle","rb") as fr:
    크롤링_리뷰수 = pickle.load(fr)
reviews = 크롤링_리뷰수['리뷰수']
out_re = 크롤링_리뷰수['리뷰']
out_re = pd.DataFrame(out_re)
out_re.columns = ["리뷰","평점"]
out_re
# Out:
#                                                    리뷰   평점
# 0   창원광장 주위에 있는 용지호수는 기분좋게 산책할 수 있는 공원입니다. 잘 단장이 되...  4.0
# 1   산책하러 자주 가는 힐링 장소.\n\n호수가 크진 않지만 괜찮아요.\n\n날씨 좋은...  5.0
# 2   넓은 들판으로 날씨가 풀리면 피크닉을 오는 사람들이 많습니다. 근처에서 음식을 배달...  5.0
# 3   벚꽃이 피면 꽤 예쁜 곳. 외지인이 찾아올 것 까진 아니지만서도. 그래도 창원 시민...  3.0
# 4   미세먼지가 그나마 괜찮은날에 잠시 다녀왔어요\n더 더워지기전에 피크닉하기 좋은곳이에...  5.0
# 5   지난 주말 작은 음악회가 열렸다\n부마민주항쟁40주년을 맞이하여 진행된 음악회로 가...  4.0
# 6   산책하기 딱 좋아요!!\n주변에 상권도 괜찮아서 점심먹고 용지호수 한반퀴 돌고 커피...  4.0
# 7   도심에 위치하고 있는 용지못을 둘러져잇는 공원입니다.\n산책을 하듯이 한바퀴 돌면 ...  4.0
# 8   도심에 있어 접근성이 좋고 산책로가 잘되어 있어 아이와 산책하기 좋습니다.\n저녁이...  5.0
# 9   산책하기 좋아요\n요즘 같은 날씨엔 저녁 이후가 좋아요\n달도 떠있고 사진 찍기에도...  5.0
# 10  깨끗하고 넓은 잔디밭이 있어 산책 나오기 좋아요, 아주 막 여행하기 좋은 관광지는 ...  4.0
# 11  시내 중심가에 위치한 호수\n저녁에는 호수중앙에서 레이저분수쇼도 하고\n오리배(??...  4.0
# 12  생각보다 조용해요. 물론 주말낮엔 사람이 많습니다.\n호수주변으로 산책로가 쭉 둘러...  5.0
# 13  호수가 생각보다 크고~ 주변 정리도 잘되어 있어서 좋았습니다..\n근처 가로수길에 ...  4.0
# 14  산책하기에 좋은 장소이지만 최근에 호수위를 다닐 수 있는 보트가 생겼어요. 주말에는...  5.0
# 15  겨울과 비오는 날을 제외하고는 저녁 8시 9시에 음악분수쇼가 있다 잔디밭과 벤치도 ...  5.0
# 16  호수 하나밖에 없어요... 호수따라 포장된 산책로가 있는데 그다지.. 차라리 건너편...  2.0
# 17  주변 상권도 활성화되어있고 여름철 밤에 걸으면 분수쇼도 보니 넘 좋아요. 기회가 되...  5.0
# 18  남편과 나는 주로 밤에 운동하러 이곳을 간다. 낮에는 분수쇼도 한다고 들었다. 밤에...  4.0
# 19  오랜만에 가본 창원~ 날도 갑자기 더워진거 같고 시원한 용지호수 구경!! 그냥 힐링...  5.0
# 20  공원이 워낙 넓어서 한바퀴 도는데 30분은 넘게 걸림. 볼거리가 풍부하진 않지만 이...  5.0
# 21  창원시내에 이렇게 넓은 호수가 있다는 것이 멋스러움. 관공서주변으로 조성되어 있음....  5.0
# 22  용지호수 한바퀴 돌며 산책하기에도 좋고\n피크닉즐기기에도 만점입니다.\n근처 용호동...  4.0
# 23  어릴때부터 자주가던곳이고 친구들과 연인과 가족과 함께 할수 있는곳입니다. 걷다보면 ...  5.0
# 24  가끔 가는 곳인데 여유롭게 둘러보면서 산책하기 좋은 곳입니다.\n호수 안쪽으로 연결...  4.0
# 25  용지 호수 근처에 있는 공원이라 가족 나들이 및 약속장소로 좋음. 근처에 상남동이 ...  4.0
# 26  얼마전 창원에 다녀왔었는데 식사하러 용지호수 근처로 갔는데\n전날까지 유등축제를 했...  4.0
# 27  창원의 렌드마크 용지문화공원.\n시청에서 내려도 되고 도청에서 내려도 되고 교통편이...  4.0
# 28  간단히 산책하기가 좋고 날씨가 너무 시원하고 도심속에 힐링하기 좋은 장소 입니다. ...  4.0
# 29  어린이 놀이터가 있고 잔디밭이 넓고 평평해서 어린이들과 놀기에 좋은 공원입니다. 자...  4.0
# 30  산책을하거나 피크닉을 즐기거나 진지한 산책을 원한다면 사랑스럽고 활기찬 곳입니다. ...  5.0
# 31  Park Yongji Park는 "카페 거리"에서 몇 블록 떨어져 있습니다. Tod...  5.0
# 32  아름답고 멋진 공원 벤치 산책. 카페에는 간식이 거의 없지만 좋은 음료 만 있습니다...  5.0
# 33    오후 공원. 조용히 앉아서 좋은 강 보트 타기 또는 그 어두운 때 조명 참조하십시오.  4.0
# 34  용지 호수점 이 아름답다. 포장된 경로에 있는 호수는 완벽한 실행. 호수 공원 주변...  5.0

# %%
# import os
# f=os.listdir("D:\programing\semiproject\clolinglist")
# f_l=[]
# for i in f:
#     l_i=i.replace(".csv","")
#     f_l.append(l_i)
# f_l
# Out:
# ['감천문화마을',
#  '광안리해수욕장',
#  '민락수변공원',
#  '부산민주공원',
#  '불국사',
#  '비프광장',
#  '태종대',
#  '해동 용궁사',
#  '해운대',
#  '황령산',
#  '흰 여울길']
